# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
from ipywidgets import interact

# %%
pd.set_option('display.max_colwidth', None)

# %%
data_dir = '../data/'

# %%
df_2021 = pd.read_csv(data_dir + '2021_rws.csv', encoding='cp1252')

# %%
df_2021.shape
# Out:
# (1512, 109)

# %% [markdown]
# ### Examining distribution of null responses

# %%
msno.matrix(df_2021)
# Out:
# <Axes: >

# %%
column_name_trimmed = { k : k.strip() for k in df_2021.columns}

# %%
df_2021.rename(column_name_trimmed, axis=1, inplace=True)

# %%
null_df = pd.DataFrame(df_2021.isnull().sum()).reset_index()

# %%
null_df = null_df.sort_values(by = 0, ascending = False)

# %%
null_df[:20]
# Out:
#                                                                                                                                                                                                                                                                                                     index  \
# 48                                                                                                                                                                                                               What is the biggest pay cut you would accept?   Please give your answer as a percentage.
# 99                                                                                                                                                                               How strongly do you agree or disagree with the following statements?    - Offering remote work helps me retain employees
# 98                                                                                                                                                         How strongly do you agree or disagree with the following statements?    - I have discretion to offer or deny remote work to employees I manage
# 106                                                                                                                                                              How strongly do you agree or disagree with the following statements?    - I find it easy to contact my employees when they work remotely
# 105                                                                                                                                                                   How strongly do you agree or disagree with the following statements?    - Managing people remotely makes me more focused on results
# 104                                                                                                                                                                           How strongly do you agree or disagree with the following statements?    - I feel well-prepared to manage employees remotely
# 103                                                                                                                                                                           How strongly do you agree or disagree with the following statements?    - I find it easy to manage poor performers remotely
# 102                                                                                                                                          How strongly do you agree or disagree with the following statements?    - I find it easy to manage employees remotely (e.g. tasking and monitoring progress)
# 101                                                                                                                                                                         How strongly do you agree or disagree with the following statements?    - My team works well together when they work remotely
# 100                                                                                                                                                                          How strongly do you agree or disagree with the following statements?    - Offering remote work helps me to recruit employees
# 97                                                                                                                                                                                                                                                            Do employees you manage ever work remotely?
# 108                                                                                                                                              Now think about the productivity of the employees you manage.   Roughly how productive are the employees you manage, each hour, when they work remotely?
# 19                                                                                                                                            How much of your work time does your employer’s policy require you to be at their workplace?  If you work a 5 day week, 1 day equals 20% of your work time.
# 73                                        Think about when you worked at your employer’s workplace and some of your colleagues were working remotely. What were the biggest barriers of working this way? - Noisy work environment ; Interruptions ; Connectivity/internet issues ; Difficulty innovating
# 78   Think about when you worked at your employer’s workplace and some of your colleagues were working remotely. What were the smallest barriers of working this way? - Interruptions ; Connectivity/internet issues ; Problems with audio-visual setup ; Difficulty collaborating with remote colleagues
# 77    Think about when you worked at your employer’s workplace and some of your colleagues were working remotely. What were the biggest barriers of working this way? - Interruptions ; Connectivity/internet issues ; Problems with audio-visual setup ; Difficulty collaborating with remote colleagues
# 76             Think about when you worked at your employer’s workplace and some of your colleagues were working remotely. What were the smallest barriers of working this way? - Noisy work environment ; Interruptions ; Lack of appropriate work and meeting spaces ; Problems with audio-visual setup
# 75              Think about when you worked at your employer’s workplace and some of your colleagues were working remotely. What were the biggest barriers of working this way? - Noisy work environment ; Interruptions ; Lack of appropriate work and meeting spaces ; Problems with audio-visual setup
# 79                       Think about when you worked at your employer’s workplace and some of your colleagues were working remotely. What were the biggest barriers of working this way? - Noisy work environment ; Lack of appropriate work and meeting spaces ; Difficulty innovating ; Lack of privacy
# 74                                       Think about when you worked at your employer’s workplace and some of your colleagues were working remotely. What were the smallest barriers of working this way? - Noisy work environment ; Interruptions ; Connectivity/internet issues ; Difficulty innovating
#
#         0
# 48   1027
# 99    917
# 98    917
# 106   917
# 105   917
# 104   917
# 103   917
# 102   917
# 101   917
# 100   917
# 97    815
# 108   815
# 19    750
# 73    616
# 78    616
# 77    616
# 76    616
# 75    616
# 79    616
# 74    616
